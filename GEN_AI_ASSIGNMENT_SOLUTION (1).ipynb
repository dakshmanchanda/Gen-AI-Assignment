# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

for root, dirs, files in os.walk("/content/drive/MyDrive"):
    for file in files:
        if "synthetic_ecommerce_reviews" in file:
            print(os.path.join(root, file))
# Out:
# /content/drive/MyDrive/synthetic_ecommerce_reviews_2500.csv
# /content/drive/MyDrive/GEN AI ASSIGNMENT/synthetic_ecommerce_reviews_2500 (2).csv

# %%
import pandas as pd

df = pd.read_csv(
    "/content/drive/MyDrive/GEN AI ASSIGNMENT/ECOM_REVIEWS_DATA.csv"
)

df.head()
# Out:
#    Order_ID     Cust_ID     Prod_ID       Cust_Name       City  Order_Date  \
# 0  ORD_1023  CUST_0X081  PROD_0ZM52    Rahul Sharma  ahmedabad  2025-04-27
# 1  ORD_1024  CUST_0X082  PROD_0ZM53  Rajat Malhotra    lucknow  2025-03-27
# 2  ORD_1025  CUST_0X083  PROD_0ZM54    Nikhil Kumar  hyderabad  2025-03-08
# 3  ORD_1026  CUST_0X084  PROD_0ZM55     Rohan Joshi  hyderabad  2025-06-01
# 4  ORD_1027  CUST_0X085  PROD_0ZM56    Simran Gupta     jaipur  2025-09-16
#
#                               Email    Amount                   Review  \
# 0     rahu.sharm8534000@outlook.com  78786.87          Could be better
# 1       raja.malho7115001@yahoo.com  36838.39          Would recommend
# 2  nikh.kumar5625002@rediffmail.com  11518.46          Would recommend
# 3       roha.joshi5895003@yahoo.com   7603.62       Highly recommended
# 4  simr.gupta2711004@rediffmail.com  74763.15  Wrong product delivered
#
#    Ratings Delivery_Date
# 0        3    2025-04-29
# 1        5    2025-03-29
# ...

# %%
df = pd.read_csv(
    "/content/drive/MyDrive/GEN AI ASSIGNMENT/ECOM_REVIEWS_DATA.csv"
)

df.head()
# Out:
#    Order_ID     Cust_ID     Prod_ID       Cust_Name       City  Order_Date  \
# 0  ORD_1023  CUST_0X081  PROD_0ZM52    Rahul Sharma  ahmedabad  2025-04-27
# 1  ORD_1024  CUST_0X082  PROD_0ZM53  Rajat Malhotra    lucknow  2025-03-27
# 2  ORD_1025  CUST_0X083  PROD_0ZM54    Nikhil Kumar  hyderabad  2025-03-08
# 3  ORD_1026  CUST_0X084  PROD_0ZM55     Rohan Joshi  hyderabad  2025-06-01
# 4  ORD_1027  CUST_0X085  PROD_0ZM56    Simran Gupta     jaipur  2025-09-16
#
#                               Email    Amount                   Review  \
# 0     rahu.sharm8534000@outlook.com  78786.87          Could be better
# 1       raja.malho7115001@yahoo.com  36838.39          Would recommend
# 2  nikh.kumar5625002@rediffmail.com  11518.46          Would recommend
# 3       roha.joshi5895003@yahoo.com   7603.62       Highly recommended
# 4  simr.gupta2711004@rediffmail.com  74763.15  Wrong product delivered
#
#    Ratings Delivery_Date
# 0        3    2025-04-29
# 1        5    2025-03-29
# ...

# %%
pd.set_option("display.max_rows", 100)
df
# Out:
#       Order_ID      Cust_ID       Prod_ID        Cust_Name       City  \
# 0     ORD_1023   CUST_0X081    PROD_0ZM52     Rahul Sharma  ahmedabad
# 1     ORD_1024   CUST_0X082    PROD_0ZM53   Rajat Malhotra    lucknow
# 2     ORD_1025   CUST_0X083    PROD_0ZM54     Nikhil Kumar  hyderabad
# 3     ORD_1026   CUST_0X084    PROD_0ZM55      Rohan Joshi  hyderabad
# 4     ORD_1027   CUST_0X085    PROD_0ZM56     Simran Gupta     jaipur
# ...        ...          ...           ...              ...        ...
# 2495  ORD_3518  CUST_0X2576  PROD_0ZM2547      Kavya Patel    lucknow
# 2496  ORD_3519  CUST_0X2577  PROD_0ZM2548   Anjali Agarwal    lucknow
# 2497  ORD_3520  CUST_0X2578  PROD_0ZM2549  Siddharth Gupta    lucknow
# 2498  ORD_3521  CUST_0X2579  PROD_0ZM2550   Aditya Agarwal    Kolkata
# 2499  ORD_3522  CUST_0X2580  PROD_0ZM2551     Mohit Mishra    Lucknow
#
#       Order_Date                             Email    Amount  \
# 0     2025-04-27     rahu.sharm8534000@outlook.com  78786.87
# ...

# %%
df.shape
df.info()
df.head()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       2500 non-null   object
#  1   Cust_ID        2500 non-null   object
#  2   Prod_ID        2500 non-null   object
#  3   Cust_Name      2325 non-null   object
#  4   City           2300 non-null   object
#  5   Order_Date     2500 non-null   object
#  6   Email          2500 non-null   object
#  7   Amount         2375 non-null   float64
#  8   Review         2500 non-null   object
#  9   Ratings        2500 non-null   int64
#  10  Delivery_Date  2500 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 215.0+ KB
#              Amount      Ratings
# count   2375.000000  2500.000000
# mean   40411.377326     3.413200
# std    22949.631112     1.351738
# min      207.410000     1.000000
# 25%    20497.870000     2.000000
# ...

# %%
df["City"].unique()
# Out:
# array(['ahmedabad', 'lucknow', 'hyderabad', 'jaipur', nan, 'Bengaluru',
#        'Kolkata', 'pune', 'Delhi', 'kolkata', 'bengaluru', 'Jaipur',
#        'Lucknow', 'chennai', 'Chennai', 'Ahmedabad', 'Hyderabad', 'Pune',
#        'delhi', 'mumbai', 'Mumbai'], dtype=object)

# %%
df["City"].value_counts(dropna=False)
# Out:
# City
# NaN          200
# Pune         134
# pune         133
# Lucknow      129
# Mumbai       127
# Hyderabad    123
# ahmedabad    119
# delhi        118
# chennai      117
# Kolkata      116
# Bengaluru    115
# lucknow      113
# Delhi        113
# Jaipur       113
# bengaluru    112
# Chennai      111
# hyderabad    111
# kolkata      105
# mumbai       102
# jaipur        96
# Ahmedabad     93
# Name: count, dtype: int64

# %%
df["City"] = df["City"].str.strip().str.title()
df["City"].value_counts(dropna=False)
df["City"].unique()
# Out:
# array(['Ahmedabad', 'Lucknow', 'Hyderabad', 'Jaipur', nan, 'Bengaluru',
#        'Kolkata', 'Pune', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
df["City"].isnull().sum()
df["City"] = df["City"].fillna("Unknown")
df["City"].isnull().sum()
# Out:
# np.int64(0)

# %%
# Clean City column
df["City"] = df["City"].str.strip().str.title()
df["City"] = df["City"].fillna("Unknown")

# %%
df["Cust_Name"].head(20)
# Out:
# 0        Rahul Sharma
# 1      Rajat Malhotra
# 2        Nikhil Kumar
# 3         Rohan Joshi
# 4        Simran Gupta
# 5       Anjali Saxena
# 6       Aditya Sharma
# 7       Ishaan Kapoor
# 8        Nikhil Patel
# 9       Ritika Sharma
# 10      Ayesha Kapoor
# 11      Simran Saxena
# 12      Nikhil Mishra
# 13      Anjali Bansal
# 14      Aarav Chauhan
# 15    Siddharth Desai
# 16       Priya Chopra
# 17        Rajat Kumar
# 18        Dev Chauhan
# 19        Aditi Singh
# Name: Cust_Name, dtype: object

# %%
df["Cust_Name"].isnull().sum()
df["Cust_Name"].sample(20)
# Out:
# 1867     Shreya Bansal
# 1986       Rajat Gupta
# 753        Arjun Sinha
# 1543    Ananya Chauhan
# 1609      Aditya Gupta
# 2224               NaN
# 2151      Tanvi Khanna
# 1830        Riya Yadav
# 2058      Aarav Thakur
# 1926       Rahul Bhatt
# 1004       Kavya Patel
# 2486    Kabir Kulkarni
# 176        Rahul Goyal
# 374        Priya Kumar
# 25          Sanya Shah
# 2482        Priya Jain
# 212       Manish Patel
# 860         Riya Joshi
# 398                NaN
# 2371       Kabir Arora
# Name: Cust_Name, dtype: object

# %%
df["Cust_Name"] = df["Cust_Name"].str.strip().str.title()

# %%
df["Cust_Name"] = df["Cust_Name"].fillna("Unknown")

# %%
df["Cust_Name"].isnull().sum()
# Out:
# np.int64(175)

# %%
df["Email"].head(20)
# Out:
# 0        rahu.sharm8534000@outlook.com
# 1          raja.malho7115001@yahoo.com
# 2     nikh.kumar5625002@rediffmail.com
# 3          roha.joshi5895003@yahoo.com
# 4     simr.gupta2711004@rediffmail.com
# 5           anja.saxen323005@yahoo.com
# 6          adit.sharm3685006@yahoo.com
# 7          isha.kapoo3470007@gmail.com
# 8          nikh.patel9671008@yahoo.com
# 9        riti.sharm2027009@outlook.com
# 10     ayes.kapoo622010@rediffmail.com
# 11         simr.saxen4200011@gmail.com
# 12         nikh.mishr9740012@gmail.com
# 13         anja.bansa1781013@gmail.com
# 14          aara.chauh800014@gmail.com
# 15    sidd.desai6838015@rediffmail.com
# 16         priy.chopr6240016@gmail.com
# 17       raja.kumar8976017@outlook.com
# 18          dev.chauh7782018@yahoo.com
# 19         adit.singh3376019@gmail.com
# Name: Email, dtype: object

# %%
df["Email"] = df["Email"].str.strip().str.lower()
df["Email"].isnull().sum()
# Out:
# np.int64(0)

# %%
email_pattern = r"^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$"

valid_email = df["Email"].str.match(
    email_pattern,
    na=False
)

# %%
valid_email.value_counts()
df[~valid_email]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Cust_ID, Prod_ID, Cust_Name, City, Order_Date, Email, Amount, Review, Ratings, Delivery_Date]
# Index: []

# %%
critical_reviews = df[df["Ratings"].isin([1, 2])].copy()

# %%
df["Ratings"].isin([1, 2])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2495    False
# 2496    False
# 2497    False
# 2498    False
# 2499    False
# Name: Ratings, Length: 2500, dtype: bool

# %%
critical_reviews.head()
# Out:
#     Order_ID     Cust_ID     Prod_ID      Cust_Name       City  Order_Date  \
# 4   ORD_1027  CUST_0X085  PROD_0ZM56   Simran Gupta     Jaipur  2025-09-16
# 5   ORD_1028  CUST_0X086  PROD_0ZM57  Anjali Saxena  Hyderabad  2026-01-22
# 6   ORD_1029  CUST_0X087  PROD_0ZM58  Aditya Sharma    Unknown  2025-03-19
# 10  ORD_1033  CUST_0X091  PROD_0ZM62  Ayesha Kapoor       Pune  2026-03-23
# 13  ORD_1036  CUST_0X094  PROD_0ZM65  Anjali Bansal    Unknown  2026-02-19
#
#                                Email    Amount                   Review  \
# 4   simr.gupta2711004@rediffmail.com  74763.15  Wrong product delivered
# 5         anja.saxen323005@yahoo.com   8233.60       Very disappointing
# 6        adit.sharm3685006@yahoo.com   6071.36       Very disappointing
# 10   ayes.kapoo622010@rediffmail.com  52841.38            Late delivery
# 13       anja.bansa1781013@gmail.com  12839.38             Poor quality
#
#     Ratings Delivery_Date
# 4         2    2025-09-20
# 5         2    2026-01-23
# ...

# %%
critical_reviews.shape
# Out:
# (670, 11)

# %%
critical_reviews["Ratings"].value_counts()
# Out:
# Ratings
# 2    349
# 1    321
# Name: count, dtype: int64

# %%
critical_reviews["Review"].value_counts()
# Out:
# Review
# Broken product             101
# Very disappointing          93
# Late delivery               86
# Rude behaviour              85
# Wrong product delivered     84
# Poor quality                77
# Missing parts               75
# Product stopped working     69
# Name: count, dtype: int64

# %%
from collections import Counter

def find_common_complaints(reviews):

    complaint_keywords = [
        "poor",
        "missing",
        "late",
        "rude",
        "broken",
        "wrong",
        "disappointing",
        "stopped"
    ]

    keyword_counts = Counter()

    for review in reviews.dropna():
        review = review.lower()

        for keyword in complaint_keywords:
            if keyword in review:
                keyword_counts[keyword] += 1

    return keyword_counts.most_common()

# %%
common_complaints = find_common_complaints(
    critical_reviews["Review"]
)

common_complaints
# Out:
# [('broken', 101),
#  ('disappointing', 93),
#  ('late', 86),
#  ('rude', 85),
#  ('wrong', 84),
#  ('poor', 77),
#  ('missing', 75),
#  ('stopped', 69)]

# %%
complaint_df = pd.DataFrame(
    common_complaints,
    columns=["Complaint", "Count"]
)

complaint_df
# Out:
#        Complaint  Count
# 0         broken    101
# 1  disappointing     93
# 2           late     86
# 3           rude     85
# 4          wrong     84
# 5           poor     77
# 6        missing     75
# 7        stopped     69

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

bars = plt.bar(
    complaint_df["Complaint"],
    complaint_df["Count"]
)

# Add the count above each bar
plt.bar_label(
    bars,
)

plt.title("Most Common Complaints in Critical Reviews")
plt.xlabel("Complaint Keyword")
plt.ylabel("Number of Reviews")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
all_reviews = " ".join(
    critical_reviews["Review"].dropna().astype(str)
)

# %%
all_reviews = all_reviews.lower()

# %%
words = all_reviews.split()

# %%
from collections import Counter

# %%
word_counts = Counter(words)

# %%
word_counts.most_common(10)
# Out:
# [('product', 254),
#  ('broken', 101),
#  ('very', 93),
#  ('disappointing', 93),
#  ('late', 86),
#  ('delivery', 86),
#  ('rude', 85),
#  ('behaviour', 85),
#  ('wrong', 84),
#  ('delivered', 84)]

# %%
from collections import Counter

def find_common_complaints(reviews):

    complaint_keywords = [
        "poor",
        "missing",
        "late",
        "rude",
        "broken",
        "wrong",
        "disappointing",
        "stopped"
    ]

    keyword_counts = Counter()

    for review in reviews.dropna():
        review = review.lower()

        for keyword in complaint_keywords:
            if keyword in review:
                keyword_counts[keyword] += 1

    return keyword_counts.most_common()

# %%
common_complaints = find_common_complaints(
    critical_reviews["Review"]
)

common_complaints
# Out:
# [('broken', 101),
#  ('disappointing', 93),
#  ('late', 86),
#  ('rude', 85),
#  ('wrong', 84),
#  ('poor', 77),
#  ('missing', 75),
#  ('stopped', 69)]

# %%
selected_reviews = critical_reviews[
    critical_reviews["Review"].str.lower().isin([
        "broken product",
        "wrong product delivered",
        "late delivery"
    ])
].drop_duplicates(
    subset="Review"
).head(3)

# %%
selected_reviews[
    ["Cust_Name", "Email", "Review", "Ratings"]
]
# Out:
#         Cust_Name                             Email                   Review  \
# 4    Simran Gupta  simr.gupta2711004@rediffmail.com  Wrong product delivered
# 10  Ayesha Kapoor   ayes.kapoo622010@rediffmail.com            Late delivery
# 21   Rohan Khanna     roha.khann1664021@outlook.com           Broken product
#
#     Ratings
# 4         2
# 10        1
# 21        2

# %%
# !pip install langchain langchain-core langchain-google-genai langchain-community langchain-groq

# %%
from google.colab import userdata
import os
os.environ['GEMINI_API_KEY'] = userdata.get("GEMINI_API_KEY")

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash',temperature=0.72,
                             api_key=os.environ['GEMINI_API_KEY'])

parser = StrOutputParser()

# %%
prompt  = PromptTemplate.from_template("""
Role
You are an experienced Customer Support Agent for an e-commerce company.

Task
Generate a short, personalized, professional, and empathetic apology email for the customer based on the provided Customer ID and Review.

Inputs
Customer Review: {Review}
Instructions
Address the customer using their Customer ID.
Begin with a sincere apology.
Specifically acknowledge the complaint mentioned in the review. Do not generate a generic apology.
Show empathy and understanding.
Briefly assure the customer that the issue will be investigated and steps will be taken to prevent it from happening again.
If applicable, mention that the customer can contact the support team for additional assistance.
End the email with a polite closing and appreciation for the customer's feedback.
Keep the email between 80 and 120 words.
Maintain a warm, respectful, and professional tone.
Do not invent order details, dates, refund amounts, or promises that are not supported by the review.
Output Format

Dear {Cust_ID}
Subject: We're Sorry About Your Experience


<Generate a personalized apology email here based on the review.>

Best Regards,

Customer Support Team

""")

# %%
def extract_cust_id_and_review(df, cust_id):
    review = df[df['Cust_ID'] == cust_id]['Review'].iloc[0]
    return review

# %%
chain = prompt | llm | parser

selected_review = critical_reviews.iloc[0]

cust_id = selected_review["Cust_ID"]
text_review = selected_review["Review"]


res = chain.invoke({
    "Cust_ID": cust_id,
    "Review": text_review
})

print(res)
# Out:
# Dear CUST_0X085,
#
# Subject: We're Sorry About Your Experience
#
# We sincerely apologize for the inconvenience and frustration you experienced with your recent order. We understand from your review that you received the wrong product, and we are truly sorry for this error. We know how disappointing it can be to receive something different from what you expected, and we deeply regret any trouble this has caused.
#
# Please know that we are taking your feedback seriously and will investigate this delivery issue to understand what went wrong and implement steps to prevent similar occurrences in the future. Our team is ready to assist you further with resolving this. Please feel free to reply to this email or contact our support team directly. Thank you for bringing this to our attention; your feedback is invaluable as we strive to improve.
#
# Best Regards,
#
# Customer Support Team
